# %% [markdown]
# ## K Means From Scratch

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_excel("/Users/divyabisht/Desktop/Kdata.xlsx")

# %%
data = data.drop(["Unnamed: 0"],axis=1)

# %%
clus= []
data.head()
# Out:
#    X-label  Y-label
# 0       16       16
# 1       28       37
# 2       20       31
# 3       53       53
# 4       86        3

# %% [markdown]
# # Clustering

# %%
#declaring clusters 3
k = 3
#declaring centroids 
c1 = data.iloc[0] 
c2 = data.iloc[int(len(data)/2-1)] 
c3 = data.iloc[int(len(data)-1)]

# %%
print(c1)
print(c2)
print(c3)
# Out:
# X-label    16
# Y-label    16
# Name: 0, dtype: int64
# X-label    66
# Y-label    16
# Name: 29, dtype: int64
# X-label    83
# Y-label    10
# Name: 59, dtype: int64

# %%
def CalcDist(Kdata):
    list1=[]
    list2=[]
    list3=[]
    for c in range(len(data)):
        list1.append(np.linalg.norm(c1-data.iloc[c][:2]))
    for c in range(len(data)):
        list2.append(np.linalg.norm(c2-data.iloc[c][:2]))
    for c in range(len(data)):
        list3.append(np.linalg.norm(c3-data.iloc[c][:2]))
    data["list1"] = list1
    data["list2"] = list2
    data["list3"] = list3

# %%
CalcDist(data)

# %%
data.head()
# Out:
#    X-label  Y-label      list1      list2      list3
# 0       16       16   0.000000  50.000000  67.268120
# 1       28       37  24.186773  43.416587  61.269895
# 2       20       31  15.524175  48.383882  66.407831
# 3       53       53  52.325902  39.217343  52.430907
# 4       86        3  71.196910  23.853721   7.615773

# %%
def clust(dt):
    clust = []
    clus=[]
    for i in range(len(dt)):
        if data.iloc[i,2]< data.iloc[i,3] and data.iloc[i,4] :
            clus.append(1)
        elif data.iloc[i,3]< data.iloc[i,2] and data.iloc[i,4]:
            clus.append(2)
        else :
            clus.append(3)
    data["clust"] = clus

# %%
clust(data)

# %%
data.head(60)
# Out:
#     X-label  Y-label      list1      list2      list3  clust
# 0        16       16   0.000000  50.000000  67.268120      1
# 1        28       37  24.186773  43.416587  61.269895      1
# 2        20       31  15.524175  48.383882  66.407831      1
# 3        53       53  52.325902  39.217343  52.430907      2
# 4        86        3  71.196910  23.853721   7.615773      2
# 5        47       27  32.893768  21.954498  39.812058      2
# 6        67        1  53.160135  15.033296  18.357560      2
# 7        35       59  47.010637  53.009433  68.593003      1
# 8        34       51  39.357337  47.423623  63.890531      1
# 9        58       75  72.422372  59.539903  69.641941      2
# 10       38       43  34.828150  38.897301  55.803226      1
# 11       19       67  51.088159  69.354164  85.702975      1
# 12       31       87  72.567210  79.158070  92.913939      1
# 13       76       61  75.000000  46.097722  51.478151      2
# 14       23       23   9.899495  43.566042  61.392182      1
# 15       58       51  54.671748  35.902646  48.020829      2
# 16       17       31  15.033296  51.244512  69.260378      1
# 17       49       13  33.136083  17.262677  34.132096      2
# 18       12        9   8.062258  54.451814  71.007042      1
# 19       84       29  69.231496  22.203603  19.026298      2
# 20       59       19  43.104524   7.615773  25.632011      2
# 21       37       84  71.168813  73.925638  87.132084      1
# 22       61       10  45.398238   7.810250  22.000000      2
# 23       21       19   5.830952  45.099889  62.649820      1
# 24        5       46  31.953091  67.977938  85.906926      1
# 25       40       59  49.244289  50.249378  65.192024      1
# 26       19       83  67.067131  81.841310  97.082439      1
# 27       49       75  67.601775  61.400326  73.355300      2
# 28       19       74  58.077534  74.652528  90.509668      1
# 29       66       16  50.000000   0.000000  18.027756      2
# 30       39       88  75.584390  76.896034  89.554453      1
# 31       80       78  89.106678  63.560994  68.066144      2
# 32       15       39  23.021729  55.946403  73.925638      1
# 33       71       83  86.683332  67.186308  73.979727      2
# 34       73       52  67.416615  36.674242  43.174066      2
# 35        4        1  19.209373  63.788714  79.511006      1
# 36        9       27  13.038405  58.051701  75.927597      1
# 37       14       59  43.046487  67.475922  84.628600      1
# 38       39       45  37.013511  39.623226  56.222771      1
# 39       13       48  32.140317  61.911227  79.649231      1
# 40       88       55  81.884064  44.777226  45.276926      2
# 41        2       63  49.040799  79.404030  96.798760      1
# 42       29       69  54.571055  64.637450  79.981248      1
# 43       67       14  51.039201   2.236068  16.492423      2
# 44       57       63  62.369865  47.853944  59.033889      2
# 45       21       56  40.311289  60.207973  77.201036      1
# 46       88        1  73.545904  26.627054  10.295630      2
# 47       11       60  44.283180  70.434367  87.658428      1
# 48       18       76  60.033324  76.837491  92.633687      1
# 49       68       53  63.820060  37.054015  45.541190      2
# 50       29       72  57.489129  67.119297  82.219219      1
# 51       58       15  42.011903   8.062258  25.495098      2
# 52       13        3  13.341664  54.571055  70.349129      1
# 53        2        3  19.104973  65.306967  81.301906      1
# 54       57       20  41.194660   9.848858  27.856777      2
# 55       22       89  73.246160  85.234969  99.809819      1
# 56       38       73  61.098281  63.505905  77.420927      1
# 57       62       29  47.801674  13.601471  28.319605      2
# 58       14       65  49.040799  71.449283  88.238314      1
# 59       83       10  67.268120  18.027756   0.000000      3

# %%
k1 = data[data["clust"]==1]
k2 = data[data["clust"]==2]
k3 = data[data["clust"]==3]

# %%
c1 = k1.mean()[:2]
c2 = k2.mean()[:2]
c3 = k3.mean()[:2]

# %%
print(c1)
print(c2)
print(c3)
# Out:
# X-label    21.314286
# Y-label    50.142857
# dtype: float64
# X-label    65.916667
# Y-label    37.333333
# dtype: float64
# X-label    83.0
# Y-label    10.0
# dtype: float64

# %%
CalcDist(data)

# %%
clust(data)
k1 = data[data["clust"]==1]
k2 = data[data["clust"]==2]
k3 = data[data["clust"]==3]
c1 = k1.mean()[:2]
c2 = k2.mean()[:2]
c3 = k3.mean()[:2]

# %%
data.head()
# Out:
#    X-label  Y-label      list1      list2      list3  clust
# 0       16       16  34.553963  54.284295  67.268120      1
# 1       28       37  14.745625  37.918132  61.269895      1
# 2       20       31  19.187921  46.351390  66.407831      1
# 3       53       53  31.814270  20.304796  52.430907      2
# 4       86        3  80.041805  39.775848   7.615773      2

# %%
print(c1)
print(c2)
print(c3)
# Out:
# X-label    22.083333
# Y-label    50.833333
# dtype: float64
# X-label    66.652174
# Y-label    35.695652
# dtype: float64
# X-label    83.0
# Y-label    10.0
# dtype: float64

# %%
CalcDist(data)

# %%
data.head()
# Out:
#    X-label  Y-label      list1      list2      list3  clust
# 0       16       16  35.360544  54.346678  67.268120      1
# 1       28       37  15.045533  38.674176  61.269895      1
# 2       20       31  19.942452  46.887893  66.407831      1
# 3       53       53  30.992495  22.041377  52.430907      2
# 4       86        3  79.833377  37.991368   7.615773      2

# %%
clust(data)
k1 = data[data["clust"]==1]
k2 = data[data["clust"]==2]
k3 = data[data["clust"]==3]
c1 = k1.mean()[:2]
c2 = k2.mean()[:2]
c3 = k3.mean()[:2]

# %%
print(c1)
print(c2)
print(c3)
# Out:
# X-label    22.083333
# Y-label    50.833333
# dtype: float64
# X-label    66.652174
# Y-label    35.695652
# dtype: float64
# X-label    83.0
# Y-label    10.0
# dtype: float64

# %% [markdown]
# # The last Two Calculations are Same

# %%
data.head()
# Out:
#    X-label  Y-label      list1      list2      list3  clust
# 0       16       16  35.360544  54.346678  67.268120      1
# 1       28       37  15.045533  38.674176  61.269895      1
# 2       20       31  19.942452  46.887893  66.407831      1
# 3       53       53  30.992495  22.041377  52.430907      2
# 4       86        3  79.833377  37.991368   7.615773      2

# %%
plt.plot(k1["X-label"],k1["Y-label"],"or")
plt.plot(k2["X-label"],k2["Y-label"],"ob")
plt.plot(k3["X-label"],k3["Y-label"],"oc")
plt.grid(axis='y')
plt.show()
